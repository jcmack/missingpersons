# %%
import json
import requests
import numpy as np
from IPython.display import HTML
from pandas import DataFrame, Series
import matplotlib.pyplot as plt

# %% [markdown]
# # Working with Find Us: Missing Persons API

# %% [markdown]
# Missing persons are grouped by location. You can specify location by providing country, state, county and city information. How many people are missing in California?

# %%
response = requests.get("http://find-us.herokuapp.com/US/California")
persons = json.loads(response.text)
print len(persons)
# Out:
# 1337

# %% [markdown]
# What about in Alameda county?

# %%
response = requests.get("http://find-us.herokuapp.com/US/California/Alameda")
print len(json.loads(response.text))
# Out:
# 30

# %% [markdown]
# What about the city of Berkeley?

# %%
response = requests.get("http://find-us.herokuapp.com/US/California/Alameda/Berkeley")
print len(json.loads(response.text))
# Out:
# 4

# %% [markdown]
# You can also query the database on several fields: country, state, county, city, first_name, last_name, sex, race, eye_color, hair_color, age, weight and height. For instance, try to query for the number of missing Black/African American males.

# %%
response = requests.get("http://find-us.herokuapp.com/search?sex=Male&race=Black/African American")
persons = json.loads(response.text)
print len(persons)
# Out:
# 44

# %% [markdown]
# The API also provides lists for standard identifiers per category.

# %%
response = requests.get("http://find-us.herokuapp.com/identifiers/race")
print json.loads(response.text)
# Out:
# [u'Asian or Pacific Islander', u'Black/African American', u'Native American', u'Non-White Hispanic/Latino', u'Other', u'Unknown', u'White', u'White Hispanic/Latino']

# %%
response = requests.get("http://find-us.herokuapp.com/identifiers/eye_color")
print json.loads(response.text)
# Out:
# [u'Black', u'Blue', u'Brown', u'Gray', u'Green', u'Hazel', u'Maroon', u'Multicolor', u'Pink', u'Unknown']

# %%
response = requests.get("http://find-us.herokuapp.com/identifiers/hair_color")
print json.loads(response.text)
# Out:
# [u'Black', u'Blonde', u'Brown', u'Gray', u'Red/Auburn', u'Sandy', u'Unknown', u'White']

# %% [markdown]
# For numerical fields such as age, weight and height. You can also query based on a range of possible value. Here we query for those missing persons between the ages of 10 and 15.

# %%
response = requests.get("http://find-us.herokuapp.com/search?age_start=10&age_end=15")
print len(json.loads(response.text))
# Out:
# 101

# %% [markdown]
# You can also query based of date time ranges. Here we look for dates between 2000-01-20 and 2000-05-20.

# %%
response = requests.get("http://find-us.herokuapp.com/search?date_start=2000-01-20&date_end=2000-05-20")
print len(json.loads(response.text)
# Out:
# 9

# %% [markdown]
# You can also include date time ranges such as between 1976-05-20 00:00:00 and 1976-05-20 15:30:00

# %%
response = requests.get("http://find-us.herokuapp.com/search?date_start=1976-05-20 00:00:00&date_end=1976-05-20 15:30:00")
print len(json.loads(response.text))
# Out:
# 1

# %% [markdown]
# # How to Work with Missing Persons Data

# %% [markdown]
# Take a look at the detailed information provided with each missing person.

# %%
response = requests.get("http://find-us.herokuapp.com/US/California/Alameda/Berkeley")
persons = json.loads(response.text)
print len(persons)
print json.dumps(persons, sort_keys=True, indent=4, separators=(',', ': '))
# Out:
# 4
# [
#     {
#         "age": "34.0",
#         "aged_photo": "http://www.missingkids.com/photographs/NCMC808401e1.jpg",
#         "agency_contact": "1-510-981-5900",
#         "agency_name": "Berkeley Police Department (California)",
#         "circumstance": "Peter's photo is shown age-progressed to 30 years.  He was last seen leaving his home to go to a bookstore.  He may no longer be in California.   Peter has 20/400 vision and needs contacts or eyeglasses for distance vision.  He has slight scarring near the tip of his right little finger.  He may use the nickname Rainbow.  He plays guitar.",
#         "city": "Berkeley",
#         "country": "US",
#         "county": "Alameda",
#         "date": "1995-08-28 00:00:00",
#         "eye_color": "Blue",
#         "first_name": "Peter",
#         "hair_color": "Brown",
#         "height": "72.0",
#         "last_name": "Mccoll",
#         "middle_name": "John",
#         "namus_number": "1870",
#         "ncmec_number": "808401",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC808401c1t.jpg",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "160.0"
#     },
#     {
#         "age": "21.0",
#         "aged_photo": "",
#         "agency_contact": "510-981-5938",
#         "agency_name": "Berkeley Police Department",
#         "circumstance": "Wendy was last seen October 31, 1989 in Berkeley, CA.\n[Source: http://dojapp.doj.ca.gov/missing/detail.asp?FCN=1070010100470] California Department of Justice",
#         "city": "Berkeley",
#         "country": "US",
#         "county": "Alameda",
#         "date": "1989-10-31 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Wendy",
#         "hair_color": "Black",
#         "height": "62.0",
#         "last_name": "Abrams-nishikai",
#         "middle_name": "Jamie",
#         "namus_number": "14971",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/27444",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "120.0"
#     },
#     {
#         "age": "20.0",
#         "aged_photo": "",
#         "agency_contact": "(510) 981-5900",
#         "agency_name": "Berkeley Police Department (California)",
#         "circumstance": "Lynn was last seen at her residence in the vicinity of the 2800 block of Regent St. in Berkeley, CA. She left her residence to meet a man nat a restaurant in the vicinity of the 2600 block of Telegraph Ave. An unidentified waitress indicated that a woman matching Lynn's description came to the restaurant at 10:15am. Although the restaurant was closed, the waitress let her sit at a table to wait for someone. No one saw the woman leave the restaurant. Law enforcement found Lynn's locked bicycle near the restaurant.",
#         "city": "Berkeley",
#         "country": "US",
#         "county": "Alameda",
#         "date": "1976-05-20 00:00:00",
#         "eye_color": "Green",
#         "first_name": "Lynn",
#         "hair_color": "Blonde",
#         "height": "64.0",
#         "last_name": "Connes",
#         "middle_name": "Ruth",
#         "namus_number": "594",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/730",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "110.0"
#     },
#     {
#         "age": "17.0",
#         "aged_photo": "",
#         "agency_contact": "510-981-5900",
#         "agency_name": "Berkeley Police Department Missing Persons Unit (California)",
#         "circumstance": "Hiramoto was last seen on January 3, 1984, in Berkeley, California.",
#         "city": "Berkeley",
#         "country": "US",
#         "county": "Alameda",
#         "date": "1984-01-03 12:06:00",
#         "eye_color": "Brown",
#         "first_name": "Jitsuro",
#         "hair_color": "Black",
#         "height": "63.0",
#         "last_name": "Hiramoto",
#         "middle_name": "D",
#         "namus_number": "4542",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/5695",
#         "race": "Asian or Pacific Islander",
#         "sex": "Male",
#         "state": "California",
#         "weight": "105.0"
#     }
# ]

# %% [markdown]
# There are photos provided with each missing persons case. Let's try to display all of the photos of the missing persons in California.

# %%
response = requests.get("http://find-us.herokuapp.com/US/California")
persons = json.loads(response.text)
print len(persons)
print json.dumps(persons, sort_keys=True, indent=4, separators=(',', ': '))
# Out:
# 1337
# [
#     {
#         "age": "30.0",
#         "aged_photo": "",
#         "agency_contact": "213-996-1800",
#         "agency_name": "Los Angeles Police Department (California)",
#         "circumstance": "Salvador Quintanilla was last seen June 6, 1981 in Los Angeles, California.",
#         "city": "Los Angeles",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1981-06-06 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Salvador",
#         "hair_color": "Black",
#         "height": "68.0",
#         "last_name": "Quintanilla",
#         "middle_name": "",
#         "namus_number": "17802",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/30879",
#         "race": "White Hispanic/Latino",
#         "sex": "Male",
#         "state": "California",
#         "weight": "150.0"
#     },
#     {
#         "age": "45.0",
#         "aged_photo": "",
#         "agency_contact": "323-890-5500",
#         "agency_name": "Los Angeles County Sheriffs Department (California)",
#         "circumstance": "Jon Wolfe Ramage was last seen February 19, 1983 in Canyon Country, CA.",
#         "city": "Canyon Country",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1983-02-19 14:00:00",
#         "eye_color": "Blue",
#         "first_name": "Jon",
#         "hair_color": "Brown",
#         "height": "72.0",
#         "last_name": "Ramage",
#         "middle_name": "Wolfe",
#         "namus_number": "17803",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/30880",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "160.0"
#     },
#     {
#         "age": "20.0",
#         "aged_photo": "",
#         "agency_contact": "707-449-5272",
#         "agency_name": "Vacaville Police Department (California)",
#         "circumstance": "MP-Campbell was last seen by his mother on 8/30/1991 at their apartment. MP drove to Oakley. They drove in a friend's white 1986 Toyota Corrolla, license plate, IPRD847. The friend reported his vehicle stolen.",
#         "city": "Vacaville",
#         "country": "US",
#         "county": "Solano",
#         "date": "1991-08-30 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Charles",
#         "hair_color": "Black",
#         "height": "67.0",
#         "last_name": "Campbell",
#         "middle_name": "Aaron",
#         "namus_number": "18588",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/32591",
#         "race": "Black/African American",
#         "sex": "Male",
#         "state": "California",
#         "weight": "130.0"
#     },
#     {
#         "age": "25.0",
#         "aged_photo": "",
#         "agency_contact": "(925) 313-2651",
#         "agency_name": "Contra Costa County Sheriff's Department (California)",
#         "circumstance": "Last seen in the evening of July 16, 1977 in Brentwood Park. She and two others had told people in the park that they were either going home to Oakley or Hogg Island. They got into Beltram's car and vanished. Beltram was reportedly seen by his brother the next morning, who did not see the girls. In late July, Beltram's car was reportedly seen in Concord, California by friends of Beltram. They said an unidentified white male was driving the car. The car eluded them and hasn't been seen since.",
#         "city": "Brentwood",
#         "country": "US",
#         "county": "Contra Costa",
#         "date": "1977-07-29 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Kenneth",
#         "hair_color": "Brown",
#         "height": "66.0",
#         "last_name": "Beltram",
#         "middle_name": "John",
#         "namus_number": "12859",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "155.0"
#     },
#     {
#         "age": "29.0",
#         "aged_photo": "",
#         "agency_contact": "",
#         "agency_name": "Nevada Office of the Attorney General, Investigator Maria Emeterio (702)486-3539, 555 E Washington Ave #3900, Las Vegas, NV 89101",
#         "circumstance": "Misty & Amanda Cross were last seen at the home of their legal custodian/paternal grandmother in Sacramento County CA. on August 19, 2000. They are believed to be in the company of their natural parents whose las known address was Las Vegas, NV. The California Authorities are concerned for the safety and welfare of the children and Protective Custody Warrants have been issued for them both. Anyone with information is urged to contact the authorities immediately.",
#         "city": "Sacramento County",
#         "country": "US",
#         "county": "Sacramento County",
#         "date": "2000-08-19 00:00:00",
#         "eye_color": "Hazel",
#         "first_name": "Misty",
#         "hair_color": "Brown",
#         "height": "63.0",
#         "last_name": "Cross",
#         "middle_name": "Lynn",
#         "namus_number": "",
#         "ncmec_number": "0012326",
#         "org": "USNV",
#         "org_contact": "(702) 486-3539 or\n1-800-992-0900 (Nevada Residents Only)",
#         "org_name": "Nevada Office of the Attorney General",
#         "photo": "http://www.missingkids.com/photographs/USNV0012326c1t.jpg",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "104.0"
#     },
#     {
#         "age": "15.0",
#         "aged_photo": "",
#         "agency_contact": "1-619-691-5151",
#         "agency_name": "San Diego County District Attorney's Office (California)  or Your Local FBI",
#         "circumstance": "Jonathan and Kimberly were last seen on April 11, 2011. They may be in the company of their mother, Ana Lorrigan, and a juvenile male. They may travel to The Philippines. The children are biracial. They are Asian and White. Jonathan may go by his middle name, James. Kimberly's ears are pierced and she may go by the name Maganda.",
#         "city": "Chula Vista",
#         "country": "US",
#         "county": "San Diego",
#         "date": "2011-04-11 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Kimberly",
#         "hair_color": "Black",
#         "height": "58.0",
#         "last_name": "Lorrigan",
#         "middle_name": "Ann",
#         "namus_number": "",
#         "ncmec_number": "1170194",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC1170194c2t.jpg",
#         "race": "Other",
#         "sex": "Male",
#         "state": "California",
#         "weight": "115.0"
#     },
#     {
#         "age": "38.0",
#         "aged_photo": "",
#         "agency_contact": "213-996-1800",
#         "agency_name": "Los Angeles Police Department (California)",
#         "circumstance": "Francisco Sanchez was last seen April 30, 1992 in Los Angeles, CA. He disappeared on the second day of the Los Angeles Riots.\nFriends reported seeing the recent immigrant from Guatemala on the street that afternoon near his family's apartment on West Adams Boulevard. His last paycheck from work was never picked up, and his family has not heard from him.",
#         "city": "Los Angeles",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1992-04-30 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Francisco",
#         "hair_color": "Black",
#         "height": "69.0",
#         "last_name": "Sanchez",
#         "middle_name": "Javier",
#         "namus_number": "17804",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/30881",
#         "race": "White Hispanic/Latino",
#         "sex": "Male",
#         "state": "California",
#         "weight": "155.0"
#     },
#     {
#         "age": "30.0",
#         "aged_photo": "",
#         "agency_contact": "(909) 387-3518",
#         "agency_name": "San Bernardino Co Sheriff Dept. (California)",
#         "circumstance": "Terry was last seen by her family when she left her home in Aurora, IL in 1979. She was known to be in Southern California and more specifically, the San Bernardino, Riverside, and/or San Diego areas after she left Illinois. She may have been a resident of various shelters. The family states that all contact has been lost and attempts to locate her have been unsuccessful. Through investigations by SBCSD it was learned the Terry was living in the San Diego, CA area in 2004. Further information indicates that she may have relocated to the east coast (Florida) sometime between 2008 -2009.",
#         "city": "Unknown",
#         "country": "US",
#         "county": "San Bernardino",
#         "date": "2004-06-17 20:36:00",
#         "eye_color": "Blue",
#         "first_name": "Terry",
#         "hair_color": "Red/Auburn",
#         "height": "62.0",
#         "last_name": "Collier",
#         "middle_name": "Lynn",
#         "namus_number": "9467",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/20293",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "125.0"
#     },
#     {
#         "age": "48.0",
#         "aged_photo": "",
#         "agency_contact": "(530) 621-5703",
#         "agency_name": "El Dorado County Sheriff's Department (California)",
#         "circumstance": "Ellen was last seen on August 10, 2005.",
#         "city": "El Dorado County",
#         "country": "US",
#         "county": "El Dorado",
#         "date": "2005-08-10 14:46:00",
#         "eye_color": "Brown",
#         "first_name": "Ellen",
#         "hair_color": "Brown",
#         "height": "63.0",
#         "last_name": "Armijo",
#         "middle_name": "Sue",
#         "namus_number": "8993",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/14333",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "150.0"
#     },
#     {
#         "age": "44.0",
#         "aged_photo": "",
#         "agency_contact": "323-890-5500",
#         "agency_name": "Los Angeles County Sheriff's Department (California)",
#         "circumstance": "On 02-13-1979, the boat the missing person had been on was found adrift in the Catalina Channel. On board was the missing person's husband who was suffering from heart trouble and transported to the hospital.\n\nPer the husband, the missing person and her husband left San Pedro on Saturday, 02-10-1979 enroute to Catalina Island. They got lost and tried to head home on Saturday night and all day Sunday trying to get home, but were still lost. During the early morning hours of 02-12-1979, the husband woke up but could not find the missing person on the boat. due to his medical emergency, the husband drifted in his boat until Tuesday morning (02-13-1979) when a passing boat offered help. A search for the missing person met with negative results.",
#         "city": "Rancho Palos Verde",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1979-02-12 02:00:00",
#         "eye_color": "Brown",
#         "first_name": "Patricia",
#         "hair_color": "Sandy",
#         "height": "65.0",
#         "last_name": "Calatrello",
#         "middle_name": "Adele",
#         "namus_number": "14012",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/28601",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "123.0"
#     },
#     {
#         "age": "48.0",
#         "aged_photo": "",
#         "agency_contact": "530-529-7920",
#         "agency_name": "Tehama County Sheriff's Office (California)",
#         "circumstance": "Carmen was last seen driving a dark green Ford F-150 super cab pick-up truck. Her vehicle was later located abandoned in the vicinity of Interstate 5 near Gillman, CA.",
#         "city": "Tehema",
#         "country": "US",
#         "county": "Tehama",
#         "date": "2004-06-18 00:00:00",
#         "eye_color": "Hazel",
#         "first_name": "Carmen",
#         "hair_color": "Brown",
#         "height": "61.0",
#         "last_name": "Pearcy",
#         "middle_name": "Lynn",
#         "namus_number": "5269",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/6857",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "120.0"
#     },
#     {
#         "age": "41.0",
#         "aged_photo": "",
#         "agency_contact": "415-499-7278",
#         "agency_name": "Marin County Sheriff's Office (California)",
#         "circumstance": "In 2005 Eric Cansler had a medical condition. On 08/09/2011 at 2000 hours, his vehicle was found abandoned in the traffic lane, mid span, on the Golden Gate Bridge with his wallet on the dashboard. He has not been seen since.",
#         "city": "Mill Valley",
#         "country": "US",
#         "county": "Marin",
#         "date": "2005-08-09 17:45:00",
#         "eye_color": "Hazel",
#         "first_name": "Eric",
#         "hair_color": "Black",
#         "height": "72.0",
#         "last_name": "Cansler",
#         "middle_name": "Dickson",
#         "namus_number": "12856",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/22558",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "195.0"
#     },
#     {
#         "age": "38.0",
#         "aged_photo": "",
#         "agency_contact": "415-499-7278",
#         "agency_name": "Marin County Sheriff's Office (California)",
#         "circumstance": "On 08/20/2006 a person matching Phillip Ferris' description was seen stopping a vehicle mid span on the Golden Gate, exiting the vehicle and jumping off of the west side of the bridge. The vehicle was borrowed by Ferris. Phillip Ferris has not been seen since.",
#         "city": "Mill Valley",
#         "country": "US",
#         "county": "Marin",
#         "date": "2006-08-20 20:01:00",
#         "eye_color": "Blue",
#         "first_name": "Phillip",
#         "hair_color": "Brown",
#         "height": "70.0",
#         "last_name": "Ferris",
#         "middle_name": "Anthony",
#         "namus_number": "12857",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/22563",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "178.0"
#     },
#     {
#         "age": "34.0",
#         "aged_photo": "http://www.missingkids.com/photographs/NCMC600818e1.jpg",
#         "agency_contact": "1-909-955-5400",
#         "agency_name": "Riverside County District Attorney's Office (California)",
#         "circumstance": "April's photo is shown age-progressed to 33 years.  She was last seen at the Woodchuck Campground in Rancho, California near her home.  She was missing her upper front teeth. She was last seen wearing a white leotard, a lavender dress, a white sweater and white leather dress shoes.",
#         "city": "Temecula",
#         "country": "US",
#         "county": "Riverside",
#         "date": "1986-12-13 00:00:00",
#         "eye_color": "Blue",
#         "first_name": "April",
#         "hair_color": "Blonde",
#         "height": "54.0",
#         "last_name": "Cooper",
#         "middle_name": "Ann",
#         "namus_number": "5972",
#         "ncmec_number": "600818",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC600818c1t.jpg",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "60.0"
#     },
#     {
#         "age": "15.0",
#         "aged_photo": "http://www.missingkids.com/photographs/NCMC1053510e1.jpg",
#         "agency_contact": "1-408-808-4700",
#         "agency_name": "Santa Clara County Sheriff's Office (California)",
#         "circumstance": "Isabella's photo is shown age-progressed to 14 years.  She was last seen on September 18, 2001.  She may be in the company of her father.  They are believed to be in Romania.",
#         "city": "Morgan Hill",
#         "country": "US",
#         "county": "Santa Clara",
#         "date": "2001-09-18 00:00:00",
#         "eye_color": "Hazel",
#         "first_name": "Isabella",
#         "hair_color": "Brown",
#         "height": "36.0",
#         "last_name": "Saileanu",
#         "middle_name": "",
#         "namus_number": "19447",
#         "ncmec_number": "1053510",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC1053510c1t.jpg",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "25.0"
#     },
#     {
#         "age": "9.0",
#         "aged_photo": "http://www.missingkids.com/photographs/NCMC1167176e1.jpg",
#         "agency_contact": "1-800-222-8477",
#         "agency_name": "Los Angeles Police Department (California)",
#         "circumstance": "Lydia's photo is shown age-progressed to 6 years.  She is biracial.  Lydia is Black and White.",
#         "city": "Lawndale",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "2004-08-01 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Lydia",
#         "hair_color": "Brown",
#         "height": "22.0",
#         "last_name": "White",
#         "middle_name": "",
#         "namus_number": "15471",
#         "ncmec_number": "1167176",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC1167176c1t.jpg",
#         "race": "Black/African American",
#         "sex": "Female",
#         "state": "California",
#         "weight": "14.0"
#     },
#     {
#         "age": "25.0",
#         "aged_photo": "",
#         "agency_contact": "805-928-3781",
#         "agency_name": "Santa Maria Police Department (California)",
#         "circumstance": "",
#         "city": "Santa Maria",
#         "country": "US",
#         "county": "Santa Barbara",
#         "date": "2001-10-11 10:36:00",
#         "eye_color": "Black",
#         "first_name": "Conrado",
#         "hair_color": "Black",
#         "height": "67.0",
#         "last_name": "Rueda",
#         "middle_name": "Cortez",
#         "namus_number": "10615",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/18182",
#         "race": "White Hispanic/Latino",
#         "sex": "Male",
#         "state": "California",
#         "weight": "145.0"
#     },
#     {
#         "age": "13.0",
#         "aged_photo": "",
#         "agency_contact": "1-707-443-4330",
#         "agency_name": "Federal Bureau of Investigation (California)",
#         "circumstance": "Tierra may be in the company of her mother.  They are believed to be in Costa Rica.",
#         "city": "Fortuna",
#         "country": "US",
#         "county": "Humboldt",
#         "date": "2005-08-12 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Tierra",
#         "hair_color": "Blonde",
#         "height": "48.0",
#         "last_name": "Gehl-kater",
#         "middle_name": "Zion",
#         "namus_number": "",
#         "ncmec_number": "1022333",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC1022333c1t.jpg",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "55.0"
#     },
#     {
#         "age": "51.0",
#         "aged_photo": "",
#         "agency_contact": "209 937-8587",
#         "agency_name": "Stockton Police Department (California)",
#         "circumstance": "",
#         "city": "Phelan",
#         "country": "US",
#         "county": "San Bernardino",
#         "date": "2013-05-10 16:30:00",
#         "eye_color": "Multicolor",
#         "first_name": "Steven",
#         "hair_color": "Sandy",
#         "height": "70.0",
#         "last_name": "Geisler",
#         "middle_name": "Douglas",
#         "namus_number": "20573",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/36449",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "200.0"
#     },
#     {
#         "age": "32.0",
#         "aged_photo": "http://www.missingkids.com/photographs/NCMC852270e1.jpg",
#         "agency_contact": "1-530-245-6025",
#         "agency_name": "Shasta County Sheriff's Office (California) -",
#         "circumstance": "Tera's photo is shown age-progressed to 23 years.  She was last seen leaving her residence to go jogging between 5:00 and 7:00 p.m.  She was wearing a sports top, shorts, and tennis shoes.  She may have been seen with a white male companion, driving a 1976 dark blue Ford full size fleetside pick-up truck with mag wheels and a yellow tailgate.",
#         "city": "Redding",
#         "country": "US",
#         "county": "Shasta",
#         "date": "1998-08-22 00:00:00",
#         "eye_color": "Hazel",
#         "first_name": "Tera",
#         "hair_color": "Blonde",
#         "height": "67.0",
#         "last_name": "Smith",
#         "middle_name": "Lynn",
#         "namus_number": "6669",
#         "ncmec_number": "852270",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC852270c1t.jpg",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "135.0"
#     },
#     {
#         "age": "63.0",
#         "aged_photo": "",
#         "agency_contact": "619-531-2277",
#         "agency_name": "San Diego Police Dept. (California)",
#         "circumstance": "On 10/14/97, Mr. Lane got up from his desk at work and went outside. He has not been heard from since. He failed to return to pick up his last paycheck. His desk was neat and things were in order. Lane told his boss that he was having trouble with his neighbors and would be moving to a new place.\nHe spoke about an ex-wife and 2 children, but friends and co-workers did not know their names or whereabouts.",
#         "city": "San Diego",
#         "country": "US",
#         "county": "San Diego",
#         "date": "1997-10-14 15:30:00",
#         "eye_color": "Blue",
#         "first_name": "George",
#         "hair_color": "Gray",
#         "height": "72.0",
#         "last_name": "Lane",
#         "middle_name": "Dewey",
#         "namus_number": "8436",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "175.0"
#     },
#     {
#         "age": "31.0",
#         "aged_photo": "",
#         "agency_contact": "213-485-5381",
#         "agency_name": "Los Angeles Police Department (California)",
#         "circumstance": "Stephen was last seen on August 4, 1988 in Los Angeles, CA. Also missing with him are Vito Jack Russo, Jason Jack Russo, and Stacy Lee Sabal. All four were reported missing when the commercial fishing boat 'Missing Bell' failed to return from a trip to the Big Sur area of Northern California.",
#         "city": "Los Angeles",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1988-08-04 00:00:00",
#         "eye_color": "Blue",
#         "first_name": "Stephen",
#         "hair_color": "Brown",
#         "height": "69.0",
#         "last_name": "La Spino",
#         "middle_name": "Christopher",
#         "namus_number": "10113",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/17152",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "180.0"
#     },
#     {
#         "age": "28.0",
#         "aged_photo": "",
#         "agency_contact": "530-795-4561",
#         "agency_name": "Winters Police Dept (California)",
#         "circumstance": "Leticia Barrales Ramos was last seen by family members during the early morning hours of April 12, 2009, in Winters, California. She was reported missing by her employer. Ramos is Mexican citizen",
#         "city": "Winters",
#         "country": "US",
#         "county": "Yolo",
#         "date": "2009-04-12 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Leticia",
#         "hair_color": "Black",
#         "height": "64.0",
#         "last_name": "Ramos",
#         "middle_name": "Barrales",
#         "namus_number": "3994",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/5181",
#         "race": "White Hispanic/Latino",
#         "sex": "Female",
#         "state": "California",
#         "weight": "250.0"
#     },
#     {
#         "age": "46.0",
#         "aged_photo": "",
#         "agency_contact": "916-808-0605",
#         "agency_name": "Sacramento Police Department (California)",
#         "circumstance": "Moreno was last seen on 8/6/1998 at a restaurant located at 2377 Northgate boulevard, in Sacramento. He was driving his 1997 Nissan Pathfinder, CA plate 3VLP084. After leaving the restauarant, he was never seen or heard from again. His vehicle has not been recovered either.",
#         "city": "Sacramento",
#         "country": "US",
#         "county": "Sacramento",
#         "date": "1998-08-06 11:45:00",
#         "eye_color": "Brown",
#         "first_name": "Henry",
#         "hair_color": "Black",
#         "height": "71.0",
#         "last_name": "Moreno",
#         "middle_name": "Arthur",
#         "namus_number": "13852",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/24602",
#         "race": "White Hispanic/Latino",
#         "sex": "Male",
#         "state": "California",
#         "weight": "200.0"
#     },
#     {
#         "age": "35.0",
#         "aged_photo": "",
#         "agency_contact": "213-485-5381",
#         "agency_name": "Los Angeles Police Department (California)",
#         "circumstance": "Vito was last seen on August 4, 1988 in Los Angeles, CA. Also missing with him are his son Jason Jack Russo, and two of his employees, Stephen Laspino, and Stacy Lee Sabal. They were reported missing when the commercial fishing boat, the \"Missing Bell\" failed to return from a trip to Big Sur in Northern California.",
#         "city": "Los Angeles",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1988-08-04 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Vito",
#         "hair_color": "Black",
#         "height": "66.0",
#         "last_name": "Russo",
#         "middle_name": "Jack",
#         "namus_number": "10112",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/17151",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "140.0"
#     },
#     {
#         "age": "33.0",
#         "aged_photo": "",
#         "agency_contact": "714-245-8393",
#         "agency_name": "Santa Ana Police Dept. (California)",
#         "circumstance": "Separated from her sons because of relationship dissolving, with the children's father.",
#         "city": "Santa Ana",
#         "country": "US",
#         "county": "Orange",
#         "date": "1990-01-01 20:12:00",
#         "eye_color": "Hazel",
#         "first_name": "Jaunice",
#         "hair_color": "Black",
#         "height": "67.0",
#         "last_name": "Kouroumalis",
#         "middle_name": "Marie",
#         "namus_number": "16980",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/29230",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "150.0"
#     },
#     {
#         "age": "26.0",
#         "aged_photo": "",
#         "agency_contact": "(805)384-4726",
#         "agency_name": "Ventura County Sheriff's Office (California)",
#         "circumstance": "Debra Kidwell was last seen on 05/04/1979 in Ventura, California.",
#         "city": "Ventura",
#         "country": "US",
#         "county": "Ventura",
#         "date": "1979-05-04 00:00:00",
#         "eye_color": "Hazel",
#         "first_name": "Debra",
#         "hair_color": "Blonde",
#         "height": "63.0",
#         "last_name": "Kidwell",
#         "middle_name": "Lynn",
#         "namus_number": "24298",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/43984",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "120.0"
#     },
#     {
#         "age": "24.0",
#         "aged_photo": "",
#         "agency_contact": "951-849-1004",
#         "agency_name": "Banning Police Department (California)",
#         "circumstance": "Gregory was last seen on February 1, 1983 in Banning,CA.",
#         "city": "Banning",
#         "country": "US",
#         "county": "Riverside",
#         "date": "1983-02-01 00:00:00",
#         "eye_color": "Blue",
#         "first_name": "Donald",
#         "hair_color": "Brown",
#         "height": "70.0",
#         "last_name": "Gregory",
#         "middle_name": "James",
#         "namus_number": "16982",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/29062",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "150.0"
#     },
#     {
#         "age": "12.0",
#         "aged_photo": "http://www.missingkids.com/photographs/NCMC982012e1.jpg",
#         "agency_contact": "1-925-646-2502",
#         "agency_name": "Contra Costa District Attorney's Office (California) (daytime) or 1-925-646-2441 (nighttime) or FBI (Sacramento, California) 1-415-553-7400",
#         "circumstance": "Amir's photo is shown age-progressed to 12 years.  He may be in the company his mother.  They are believed to have left the country and traveled to Egypt.  The child is of Egyptian descent.",
#         "city": "San Ramon",
#         "country": "US",
#         "county": "Contra Costa",
#         "date": "2003-04-30 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Amir",
#         "hair_color": "Black",
#         "height": "24.0",
#         "last_name": "Abdou",
#         "middle_name": "Kareem",
#         "namus_number": "19490",
#         "ncmec_number": "982012",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC982012c1t.jpg",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "30.0"
#     },
#     {
#         "age": "22.0",
#         "aged_photo": "",
#         "agency_contact": "(213) 996-1800",
#         "agency_name": "Los Angeles Police Department (California)",
#         "circumstance": "disappeared shortly after having a motorcycle accident.\n\nHis head was shaved at time of disappearance.",
#         "city": "West Hills",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1994-03-08 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Shai",
#         "hair_color": "Brown",
#         "height": "68.0",
#         "last_name": "Gitlis",
#         "middle_name": "",
#         "namus_number": "24295",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "170.0"
#     },
#     {
#         "age": "21.0",
#         "aged_photo": "",
#         "agency_contact": "916-874-1751",
#         "agency_name": "Sacramento County Sheriff's Department (California)",
#         "circumstance": "On the morning of May 20, 1981, Kelley was going to drive to Los Angeles, CA to visit his girlfriend. The actual time of his departure is unknown, but he called/spoke to his girlfriend at 0800 hours on that date. He was driving his 1976 orange Toyota Celica (CA plate 598TIH). He was never heard from or seen again.",
#         "city": "Carmichael",
#         "country": "US",
#         "county": "Sacramento",
#         "date": "1981-05-20 08:00:00",
#         "eye_color": "Green",
#         "first_name": "Dale",
#         "hair_color": "Brown",
#         "height": "70.0",
#         "last_name": "Kelley",
#         "middle_name": "Eugene",
#         "namus_number": "5667",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/7738",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "165.0"
#     },
#     {
#         "age": "27.0",
#         "aged_photo": "",
#         "agency_contact": "8317587360",
#         "agency_name": "Salinas Police Department (California)",
#         "circumstance": "",
#         "city": "Salinas",
#         "country": "US",
#         "county": "Monterey",
#         "date": "1976-02-07 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Margarita",
#         "hair_color": "Brown",
#         "height": "62.0",
#         "last_name": "Macneill",
#         "middle_name": "",
#         "namus_number": "11585",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/41055",
#         "race": "Non-White Hispanic/Latino",
#         "sex": "Female",
#         "state": "California",
#         "weight": "125.0"
#     },
#     {
#         "age": "22.0",
#         "aged_photo": "",
#         "agency_contact": "(714)765-1563",
#         "agency_name": "Anaheim Police Dept. (California)",
#         "circumstance": "",
#         "city": "Anaheim",
#         "country": "US",
#         "county": "Orange",
#         "date": "1973-06-01 12:00:00",
#         "eye_color": "Green",
#         "first_name": "Barbara",
#         "hair_color": "Brown",
#         "height": "71.0",
#         "last_name": "Tolbert",
#         "middle_name": "Ann",
#         "namus_number": "12668",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "115.0"
#     },
#     {
#         "age": "31.0",
#         "aged_photo": "http://www.missingkids.com/photographs/NCMC864049e1.jpg",
#         "agency_contact": "1-916-264-5471",
#         "agency_name": "Sacramento Police Department (California) - Missing Persons",
#         "circumstance": "Teresa's photo is shown age-progressed to 29 years.  She may still be in California.  She has a tattoo on the back of her right shoulder and she has blonde highlights in her hair.",
#         "city": "Sacramento",
#         "country": "US",
#         "county": "Sacramento",
#         "date": "1999-05-25 00:00:00",
#         "eye_color": "Blue",
#         "first_name": "Teresa",
#         "hair_color": "Brown",
#         "height": "60.0",
#         "last_name": "Barbusca",
#         "middle_name": "Marie",
#         "namus_number": "20",
#         "ncmec_number": "864049",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC864049c1t.jpg",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "100.0"
#     },
#     {
#         "age": "30.0",
#         "aged_photo": "",
#         "agency_contact": "760-768-2140",
#         "agency_name": "Calexico Police Dept. (California)",
#         "circumstance": "Maria is missing with her son, Ignacio Cantua and Maria Teresa Cantua . They were last seen on January 1, 1999, in Calexico.",
#         "city": "Calexico",
#         "country": "US",
#         "county": "Imperial",
#         "date": "1999-01-01 12:03:00",
#         "eye_color": "Brown",
#         "first_name": "Maria",
#         "hair_color": "Black",
#         "height": "62.0",
#         "last_name": "Cantua",
#         "middle_name": "Teresa",
#         "namus_number": "9187",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/14910",
#         "race": "White Hispanic/Latino",
#         "sex": "Female",
#         "state": "California",
#         "weight": "115.0"
#     },
#     {
#         "age": "36.0",
#         "aged_photo": "",
#         "agency_contact": "(661) 391-7597",
#         "agency_name": "Kern County Sheriff's Department (California)",
#         "circumstance": "Unknown. Shani was last seen at a relative's residence in the 1300 block of Emery Ave. in Bakersfield, CA.",
#         "city": "Bakersfield",
#         "country": "US",
#         "county": "Kern",
#         "date": "2005-11-24 00:00:00",
#         "eye_color": "Blue",
#         "first_name": "Shani",
#         "hair_color": "Blonde",
#         "height": "64.0",
#         "last_name": "Estes",
#         "middle_name": "Ann",
#         "namus_number": "1204",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/1574",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "140.0"
#     },
#     {
#         "age": "15.0",
#         "aged_photo": "",
#         "agency_contact": "1-805-473-4511",
#         "agency_name": "Grover Beach Police Department (California)",
#         "circumstance": "Briana's photo is shown age-progressed to 11 years, Mindy's photo is shown age-progressed to 9 years, and Tania's photo is shown age-progressed to 14 years.  They were allegedly abducted by their mother, Mireya Graciano, on July 12, 2010. A felony warrant for Kidnapping was issued for Mireya on July 14, 2010. They may travel to Tijuana, Mexico. When they were last seen, Tania had light brown highlights in her hair and Mireya had brown highlights in her hair.  Mireya has a tattoo of \"M&M\" on her chest.",
#         "city": "Grover Beach",
#         "country": "US",
#         "county": "San Luis Obispo",
#         "date": "2010-07-12 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Tania",
#         "hair_color": "Brown",
#         "height": "55.0",
#         "last_name": "Ochoa",
#         "middle_name": "",
#         "namus_number": "",
#         "ncmec_number": "1151962",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC1151962c3t.jpg",
#         "race": "Non-White Hispanic/Latino",
#         "sex": "Female",
#         "state": "California",
#         "weight": "115.0"
#     },
#     {
#         "age": "40.0",
#         "aged_photo": "",
#         "agency_contact": "213-996-1800",
#         "agency_name": "Los Angeles Police (California)",
#         "circumstance": "Carmen was last seen with her family in Los Angeles, California on March 15, 1982. The family left their home in their car during the day and have never been heard from again.\nThe family's car was discovered at the bottom of a gorge in the San Gabriel Mountains on April 27, 1982, more than one month after they disappeared.",
#         "city": "Los Angeles",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1982-03-15 18:07:00",
#         "eye_color": "Brown",
#         "first_name": "Carman",
#         "hair_color": "Black",
#         "height": "66.0",
#         "last_name": "Burhans",
#         "middle_name": "Maria",
#         "namus_number": "5744",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/7902",
#         "race": "White Hispanic/Latino",
#         "sex": "Female",
#         "state": "California",
#         "weight": "210.0"
#     },
#     {
#         "age": "14.0",
#         "aged_photo": "",
#         "agency_contact": "209-572-9532",
#         "agency_name": "Modesto Police Department (California)",
#         "circumstance": "Derran left his Modesto home on Randy Street to walk to Downey High School. He never arrived, and his family hasn't heard from him again. (ncic:M-105390712)",
#         "city": "Modesto",
#         "country": "US",
#         "county": "Stanislaus",
#         "date": "1973-02-27 19:29:00",
#         "eye_color": "Unknown",
#         "first_name": "Derran",
#         "hair_color": "Blonde",
#         "height": "72.0",
#         "last_name": "Rogers",
#         "middle_name": "Conway",
#         "namus_number": "4614",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/5792",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "150.0"
#     },
#     {
#         "age": "15.0",
#         "aged_photo": "",
#         "agency_contact": "213-847-0970",
#         "agency_name": "Los Angeles Police Department (California)",
#         "circumstance": "The child was last seen on December 14, 1968.",
#         "city": "Sylmar",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1968-12-16 14:08:00",
#         "eye_color": "Hazel",
#         "first_name": "Roger",
#         "hair_color": "Brown",
#         "height": "68.0",
#         "last_name": "Madison",
#         "middle_name": "Dale",
#         "namus_number": "4637",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/5817",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "145.0"
#     },
#     {
#         "age": "41.0",
#         "aged_photo": "",
#         "agency_contact": "916-874-1751",
#         "agency_name": "Sacramento County Sheriff's Department (California)",
#         "circumstance": "The victim was home with her children on the night of 8/26/1997 at 0040 hours. The next day she did not arrive at work and was never seen or heard from again. The MP was the victim of multiple stalkers and co-founded a local group called \"Survivors of Stalking.\"",
#         "city": "Rancho Cordova",
#         "country": "US",
#         "county": "Sacramento",
#         "date": "1997-08-26 00:39:00",
#         "eye_color": "Brown",
#         "first_name": "Doris",
#         "hair_color": "Brown",
#         "height": "61.0",
#         "last_name": "Inzunza",
#         "middle_name": "Edith",
#         "namus_number": "8799",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/14226",
#         "race": "White Hispanic/Latino",
#         "sex": "Female",
#         "state": "California",
#         "weight": "120.0"
#     },
#     {
#         "age": "16.0",
#         "aged_photo": "",
#         "agency_contact": "213-484-3450",
#         "agency_name": "Los Angeles Police Department (California)",
#         "circumstance": "Jeremias was last seen on May 27, 2010.",
#         "city": "Los Angeles",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "2010-05-27 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Jeremias",
#         "hair_color": "Black",
#         "height": "59.0",
#         "last_name": "Gomez",
#         "middle_name": "",
#         "namus_number": "21969",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "",
#         "race": "Non-White Hispanic/Latino",
#         "sex": "Male",
#         "state": "California",
#         "weight": "130.0"
#     },
#     {
#         "age": "36.0",
#         "aged_photo": "",
#         "agency_contact": "909-448-3640",
#         "agency_name": "Montclair Police Department (California)",
#         "circumstance": "Mary Amos left her home on December 31, 1968, after an argument with her husband. She was staying in a local motel and has not been seen since. Her daughter reported her missing in 1991 upon learning that Mr. Amos had not reported Mary missing.",
#         "city": "Montclair",
#         "country": "US",
#         "county": "San Bernardino",
#         "date": "1968-12-31 00:00:00",
#         "eye_color": "Green",
#         "first_name": "Mary",
#         "hair_color": "Red/Auburn",
#         "height": "67.0",
#         "last_name": "Amos",
#         "middle_name": "Corrine",
#         "namus_number": "2856",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
# ...
#         "eye_color": "Brown",
#         "first_name": "Eva",
#         "hair_color": "Brown",
#         "height": "64.0",
#         "last_name": "Christian",
#         "middle_name": "Simone",
#         "namus_number": "",
#         "ncmec_number": "1222548",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC1222548c1t.jpg",
#         "race": "Black/African American",
#         "sex": "Female",
#         "state": "California",
#         "weight": "120.0"
#     },
#     {
#         "age": "17.0",
#         "aged_photo": "",
#         "agency_contact": "415-553-1071",
#         "agency_name": "San Francisco Police Department (California)",
#         "circumstance": "Deyvin was last seen on September 22, 2003, in San Francisco, CA.",
#         "city": "San Francisco",
#         "country": "US",
#         "county": "San Francisco",
#         "date": "2003-09-22 00:00:00",
#         "eye_color": "Black",
#         "first_name": "Deyvin",
#         "hair_color": "Black",
#         "height": "68.0",
#         "last_name": "Medina",
#         "middle_name": "",
#         "namus_number": "10172",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/17303",
#         "race": "White Hispanic/Latino",
#         "sex": "Male",
#         "state": "California",
#         "weight": "136.0"
#     },
#     {
#         "age": "20.0",
#         "aged_photo": "",
#         "agency_contact": "323-890-5500",
#         "agency_name": "Los Angeles County Sheriff's Department (California)",
#         "circumstance": "Source: Charley Project\n\nRoof was last seen on April 15, 1994 leaving her mother's home in a mobile home park on east Avenue I in Los Angeles, California. She has never been heard from again. Foul play is suspected in Roof's disappearance due to her lifestyle and the people she associated with. Her case remains unsolved.",
#         "city": "Lancaster",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1994-04-15 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Rene",
#         "hair_color": "Brown",
#         "height": "65.0",
#         "last_name": "Roof",
#         "middle_name": "Michelle",
#         "namus_number": "10170",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/17301",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "125.0"
#     },
#     {
#         "age": "40.0",
#         "aged_photo": "http://www.missingkids.com/photographs/NCMC601813e1.jpg",
#         "agency_contact": "1-323-890-5500",
#         "agency_name": "Los Angeles County Sheriff's Office (California)",
#         "circumstance": "Sir-Kristopher's photo is shown age-progressed to 37 years.  He was last seen spending the evening at a friend's home.  The home burned down that night and the guardian was located deceased but neither the child nor the other occupants of the house were ever found.  Sir-Kristopher has a four inch scar on his back and scar tissue on his feet and ankles.  He has a very light complexion.",
#         "city": "Los Angeles",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "1977-07-20 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Sir-kristopher",
#         "hair_color": "Brown",
#         "height": "36.0",
#         "last_name": "Marshall",
#         "middle_name": "Clay",
#         "namus_number": "6344",
#         "ncmec_number": "601813",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC601813c1t.jpg",
#         "race": "Other",
#         "sex": "Male",
#         "state": "California",
#         "weight": "37.0"
#     },
#     {
#         "age": "57.0",
#         "aged_photo": "",
#         "agency_contact": "949-644-3790",
#         "agency_name": "Newport Beach Police Department (California)",
#         "circumstance": "Mr. Hawk was last seen with his wife when they were in the process of trying to sell their yacht.",
#         "city": "Newport Beach",
#         "country": "US",
#         "county": "Orange",
#         "date": "2004-11-14 00:00:00",
#         "eye_color": "Hazel",
#         "first_name": "Thomas",
#         "hair_color": "Brown",
#         "height": "68.0",
#         "last_name": "Hawks",
#         "middle_name": "Charles",
#         "namus_number": "14644",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/26643",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "185.0"
#     },
#     {
#         "age": "47.0",
#         "aged_photo": "",
#         "agency_contact": "949-644-3790",
#         "agency_name": "Newport Beach Police Department (California)",
#         "circumstance": "Mrs. Hawks was last seen with her husband when they were selling their yacht.",
#         "city": "Newport Beach",
#         "country": "US",
#         "county": "Orange",
#         "date": "2004-11-14 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Jackie",
#         "hair_color": "Brown",
#         "height": "66.0",
#         "last_name": "Hawks",
#         "middle_name": "Ellen",
#         "namus_number": "14646",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/26644",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "110.0"
#     },
#     {
#         "age": "0.0",
#         "aged_photo": "",
#         "agency_contact": "714-744-7380",
#         "agency_name": "Orange Police Department (California)",
#         "circumstance": "Emmanuel and Fernando (MP # 15370) were last seen on April 12, 2012. They are missing under suspicious circumstances.",
#         "city": "Orange",
#         "country": "US",
#         "county": "Orange",
#         "date": "2012-04-12 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Emmanuel",
#         "hair_color": "Brown",
#         "height": "24.0",
#         "last_name": "Limas",
#         "middle_name": "",
#         "namus_number": "15369",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/28734",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "15.0"
#     },
#     {
#         "age": "40.0",
#         "aged_photo": "",
#         "agency_contact": "(805) 339-4400",
#         "agency_name": "Ventura Police Department (California)",
#         "circumstance": "She was last seen on October 15, 2002. At that time, she had mentioned to family members that she was leaving for Alaska. She had her rental car filled with luggage and a canoe strapped to the roof. She gave her son almost all of her belongings and left in her rental car. The rental car was found parked in Eureka, California. The canoe was missing.",
#         "city": "Ventura",
#         "country": "US",
#         "county": "Ventura",
#         "date": "2002-10-15 00:00:00",
#         "eye_color": "Green",
#         "first_name": "Tracee",
#         "hair_color": "Brown",
#         "height": "68.0",
#         "last_name": "Carter",
#         "middle_name": "Jane",
#         "namus_number": "14888",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/27266",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "140.0"
#     },
#     {
#         "age": "5.0",
#         "aged_photo": "",
#         "agency_contact": "1-714-647-7000",
#         "agency_name": "Orange County District Attorney's Office (California)",
#         "circumstance": "Ryosei was allegedly abducted by his mother, Yuko Shimizu. A felony warrant was issued for Yuko on June 14, 2013. They may travel to Japan. Ryosei is Biracial. He is Asian and White. Ryosei is of Japanese descent.",
#         "city": "Trabuco Canyon",
#         "country": "US",
#         "county": "Orange",
#         "date": "2012-11-27 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Ryosei",
#         "hair_color": "Brown",
#         "height": "41.0",
#         "last_name": "Easley",
#         "middle_name": "Michael",
#         "namus_number": "",
#         "ncmec_number": "1218154",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC1218154c1t.jpg",
#         "race": "Other",
#         "sex": "Male",
#         "state": "California",
#         "weight": "35.0"
#     },
#     {
#         "age": "26.0",
#         "aged_photo": "",
#         "agency_contact": "323-890-5500",
#         "agency_name": "Los Angeles County Sheriff's Department (California)",
#         "circumstance": "The missing person was last seen at her place of residence on May 9, 2013 at 11:00 p.m.",
#         "city": "Lancaster",
#         "country": "US",
#         "county": "Los Angeles",
#         "date": "2013-05-09 23:00:00",
#         "eye_color": "Blue",
#         "first_name": "Michelle",
#         "hair_color": "Blonde",
#         "height": "62.0",
#         "last_name": "Russ",
#         "middle_name": "June",
#         "namus_number": "20902",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/37789",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "125.0"
#     },
#     {
#         "age": "34.0",
#         "aged_photo": "",
#         "agency_contact": "909-484-3787",
#         "agency_name": "CA Dept. of Corrections Special Service Unit (California)",
#         "circumstance": "Eder escaped from California State prison in 1974. Eder was serving a sentence for murdering and disemboweling 4 children and shooting their mother.\n\nMurders were committed when Eder was 16. Eder is originally from New York. EDERs mother lived in Florida at the time of his arrest. Eder possibly has ties to the Berkley, San Francisco, CA area as well as New York, Washington and Florida.\n\nPrior to his arrest in 1958 he made trips to Tijuana, Mexico to obtain false identification.\n\nEder may had ties to left wing political groups such as Venceremos, S.D.I., Zapbom, the Symbionese Liberation Army and others who possibly assisted in the escape and helped him flee to Central or South America.\n\nEder is also second generation German and has skills as a cabinet maker/wood work. Eder hand carved abstract wood figures in prison.\n\nLast seen in Napa County around 1976 using the name John Wehe (phonetic) and possibly \"Dennis\".\n\nLikely connected with OMG motorcycle gang, white supramacist or anti-government organization.",
#         "city": "Napa County",
#         "country": "US",
#         "county": "Napa",
#         "date": "1976-01-01 00:00:00",
#         "eye_color": "Blue",
#         "first_name": "Carl",
#         "hair_color": "Blonde",
#         "height": "75.0",
#         "last_name": "Eder",
#         "middle_name": "Alfred",
#         "namus_number": "14880",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/27229",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "195.0"
#     },
#     {
#         "age": "28.0",
#         "aged_photo": "",
#         "agency_contact": "415-553-1071",
#         "agency_name": "San Francisco Police Department (California)",
#         "circumstance": "John Holt was last seen in San Francisco, CA on February 10, 1983.",
#         "city": "San Francisco",
#         "country": "US",
#         "county": "San Francisco",
#         "date": "1983-02-10 00:00:00",
#         "eye_color": "Green",
#         "first_name": "John",
#         "hair_color": "Brown",
#         "height": "70.0",
#         "last_name": "Holt",
#         "middle_name": "Scott",
#         "namus_number": "20909",
#         "ncmec_number": "",
#         "org": "NAMUS",
#         "org_contact": "1-855-626-7600",
#         "org_name": "National Missing and Unidentified Persons System",
#         "photo": "https://www.findthemissing.org/en/photos/thumb/37027",
#         "race": "White",
#         "sex": "Male",
#         "state": "California",
#         "weight": "165.0"
#     },
#     {
#         "age": "26.0",
#         "aged_photo": "http://www.missingkids.com/photographs/NCMC763225e1.jpg",
#         "agency_contact": "1-707-428-7300",
#         "agency_name": "Fairfield Police Department (California) Or Your Local FBI",
#         "circumstance": "Amanda's photo is shown age-progressed to 24 years.  She was last seen at approximately 5 p.m. when she left her brother and a playmate to ride her bike to another friend's home.  She was last seen wearing a pink jacket, a dark purple shirt, and white tennis shoes.  She answers to the name \"Nikky.\"",
#         "city": "Fairfield",
#         "country": "US",
#         "county": "Solano",
#         "date": "1991-12-27 00:00:00",
#         "eye_color": "Blue",
#         "first_name": "Amanda",
#         "hair_color": "Blonde",
#         "height": "41.0",
#         "last_name": "Campbell",
#         "middle_name": "Nicole",
#         "namus_number": "5917",
#         "ncmec_number": "763225",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC763225c1t.jpg",
#         "race": "White",
#         "sex": "Female",
#         "state": "California",
#         "weight": "59.0"
#     },
#     {
#         "age": "19.0",
#         "aged_photo": "",
#         "agency_contact": "1-818-548-4840",
#         "agency_name": "Glendale Police Department (California)",
#         "circumstance": "The children's larger photos were taken after they went missing, in January 2012. They were allegedly abducted by their mother, Herminia Pech, on March 31, 2000. A felony warrant was issued for Herminia on October 16, 2001. They may have traveled to Chumayel, Yucatan, Mexico. Joceline has chicken pox scars on her forehead and her right cheek. Janette may go by the alias name Jessica Coba Pedraza. Herminia may use the alias last name of Peraza.",
#         "city": "San Ysidro",
#         "country": "US",
#         "county": "San Diego",
#         "date": "2000-03-31 00:00:00",
#         "eye_color": "Brown",
#         "first_name": "Joceline",
#         "hair_color": "Black",
#         "height": "43.0",
#         "last_name": "Quiroz",
#         "middle_name": "",
#         "namus_number": "19433",
#         "ncmec_number": "898822",
#         "org": "NCMC",
#         "org_contact": "1-800-843-5678 (1-800-THE-LOST)",
#         "org_name": "National Center for Missing & Exploited Children",
#         "photo": "http://www.missingkids.com/photographs/NCMC898822c2t.jpg",
#         "race": "Non-White Hispanic/Latino",
#         "sex": "Female",
#         "state": "California",
#         "weight": "38.0"
#     }
# ]

# %%
def photos_to_html(persons):
    html = ""
    for person in persons:
        html += "<img src=\"" + person["photo"] + "\"/>"
    return HTML(html)

photos_to_html(persons)
# Out:
# <img src="https://www.findthemissing.org/en/photos/thumb/30879"/><img src="https://www.findthemissing.org/en/photos/thumb/30880"/><img src="https://www.findthemissing.org/en/photos/thumb/32591"/><img src=""/><img src="http://www.missingkids.com/photographs/USNV0012326c1t.jpg"/><img src="http://www.missingkids.com/photographs/NCMC1170194c2t.jpg"/><img src="https://www.findthemissing.org/en/photos/thumb/30881"/><img src="https://www.findthemissing.org/en/photos/thumb/20293"/><img src="https://www.findthemissing.org/en/photos/thumb/14333"/><img src="https://www.findthemissing.org/en/photos/thumb/28601"/><img src="https://www.findthemissing.org/en/photos/thumb/6857"/><img src="https://www.findthemissing.org/en/photos/thumb/22558"/><img src="https://www.findthemissing.org/en/photos/thumb/22563"/><img src="http://www.missingkids.com/photographs/NCMC600818c1t.jpg"/><img src="http://www.missingkids.com/photographs/NCMC1053510c1t.jpg"/><img src="http://www.missingkids.com/photographs/NCMC1167176c1t.jpg"/><img src="https://www.findthemissing.org/en/photos/thumb/18182"/><img src="http://www.missingkids.com/photographs/NCMC1022333c1t.jpg"/><img src="https://www.findthemissing.org/en/photos/thumb/36449"/><img src="http://www.missingkids.com/photographs/NCMC852270c1t.jpg"/><img src=""/><img src="https://www.findthemissing.org/en/photos/thumb/17152"/><img src="https://www.findthemissing.org/en/photos/thumb/5181"/><img src="https://www.findthemissing.org/en/photos/thumb/24602"/><img src="https://www.findthemissing.org/en/photos/thumb/17151"/><img src="https://www.findthemissing.org/en/photos/thumb/29230"/><img src="https://www.findthemissing.org/en/photos/thumb/43984"/><img src="https://www.findthemissing.org/en/photos/thumb/29062"/><img src="http://www.missingkids.com/photographs/NCMC982012c1t.jpg"/><img src=""/><img src="https://www.findthemissing.org/en/photos/thumb/7738"/><img src="https://www.findthemissing.org/en/photos/thumb/41055"/><img src=""/><img src="http://www.missingkids.com/photographs/NCMC864049c1t.jpg"/><img src="https://www.findthemissing.org/en/photos/thumb/14910"/><img src="https://www.findthemissing.org/en/photos/thumb/1574"/><img src="http://www.missingkids.com/photographs/NCMC1151962c3t.jpg"/><img src="https://www.findthemissing.org/en/photos/thumb/7902"/><img src="https://www.findthemissing.org/en/photos/thumb/5792"/><img src="https://www.findthemissing.org/en/photos/thumb/5817"/><img src="https://www.findthemissing.org/en/photos/thumb/14226"/><img src=""/><img src="https://www.findthemissing.org/en/photos/thumb/4263"/><img src="https://www.findthemissing.org/en/photos/thumb/17469"/><img src="http://www.missingkids.com/photographs/NCMC895143c1t.jpg"/><img src="https://www.findthemissing.org/en/photos/thumb/41030"/><img src="https://www.findthemissing.org/en/photos/thumb/39794"/><img src="https://www.findthemissing.org/en/photos/thumb/7122"/><img src=""/><img src="https://www.findthemissing.org/en/photos/thumb/682"/><img src="https://www.findthemissing.org/en/photos/thumb/14386"/><img src=""/><img src=""/><img src="https://www.findthemissing.org/en/photos/thumb/29353"/><img src="http://www.missingkids.com/photographs/NCMC1152805c1t.jpg"/><img src="http://www.missingkids.com/photographs/NCMC787469c1t.jpg"/><img src=""/><img src="http://www.missingkids.com/photographs/NCMC1175494c1t.jpg"/><img src="https://www.findthemissing.org/en/photos/thumb/33216"/><img src="https://www.findthemissing.org/en/photos/thumb/35279"/><img src="https://www.findthemissing.org/en/photos/thumb/14392"/><img src=""/><img src=""/><img src="https://www.findthemissing.org/en/photos/thumb/32541"/><img src="https://www.findthemissing.org/en/photos/thumb/35071"/><img src="http://www.missingkids.com/photographs/NCMC601948c1t.jpg"/><img src="https://www.findthemissing.org/en/photos/thumb/977"/><img src="https://www.findthemissing.org/en/photos/thumb/18637"/><img src="https://www.findthemissing.org/en/photos/thumb/35054"/><img src="https://www.findthemis ...

# %% [markdown]
# Now load all of the missing persons in California into a DataFrame and look at some statistics.

# %%
df = DataFrame(persons)
df.head()
# Out:
#     age aged_photo  agency_contact  \
# 0  30.0               213-996-1800
# 1  45.0               323-890-5500
# 2  20.0               707-449-5272
# 3  25.0             (925) 313-2651
# 4  29.0
#
#                                          agency_name  \
# 0         Los Angeles Police Department (California)
# 1  Los Angeles County Sheriffs Department (Califo...
# 2           Vacaville Police Department (California)
# 3  Contra Costa County Sheriff's Department (Cali...
# 4  Nevada Office of the Attorney General, Investi...
#
#                                         circumstance               city  \
# 0  Salvador Quintanilla was last seen June 6, 198...        Los Angeles
# 1  Jon Wolfe Ramage was last seen February 19, 19...     Canyon Country
# 2  MP-Campbell was last seen by his mother on 8/3...          Vacaville
# 3  Last seen in the evening of July 16, 1977 in B...          Brentwood
# 4  Misty & Amanda Cross were last seen at the hom...  Sacramento County
#
#   country             county                 date eye_color first_name  \
# 0      US        Los Angeles  1981-06-06 00:00:00     Brown   Salvador
# 1      US        Los Angeles  1983-02-19 14:00:00      Blue        Jon
# 2      US             Solano  1991-08-30 00:00:00     Brown    Charles
# 3      US       Contra Costa  1977-07-29 00:00:00     Brown    Kenneth
# 4      US  Sacramento County  2000-08-19 00:00:00     Hazel      Misty
#
#   hair_color height    last_name middle_name namus_number ncmec_number    org  \
# 0      Black   68.0  Quintanilla                    17802               NAMUS
# 1      Brown   72.0       Ramage       Wolfe        17803               NAMUS
# 2      Black   67.0     Campbell       Aaron        18588               NAMUS
# 3      Brown   66.0      Beltram        John        12859               NAMUS
# 4      Brown   63.0        Cross        Lynn                   0012326   USNV
#
#                                          org_contact  \
# 0                                     1-855-626-7600
# 1                                     1-855-626-7600
# 2                                     1-855-626-7600
# 3                                     1-855-626-7600
# 4  (702) 486-3539 or\n1-800-992-0900 (Nevada Resi...
#
#                                            org_name
# 0  National Missing and Unidentified Persons System ...
# 1  National Missing and Unidentified Persons System ...
# 2  National Missing and Unidentified Persons System ...
# 3  National Missing and Unidentified Persons System ...
# 4             Nevada Office of the Attorney General ...
#
# [5 rows x 25 columns]

# %%
df.describe()
# Out:
#          age aged_photo agency_contact  \
# count   1337       1337           1337
# unique    86        168            674
# top     17.0              323-890-5500
# freq      65       1170             76
#
#                                        agency_name circumstance         city  \
# count                                         1337         1337         1337
# unique                                         524         1266          445
# top     Los Angeles Police Department (California)               Los Angeles
# freq                                           100           63          120
#
#        country       county                 date eye_color first_name  \
# count     1337         1337                 1337      1337       1337
# unique       1           52                 1279         8        760
# top         US  Los Angeles  1988-08-04 00:00:00     Brown       John
# freq      1337          359                    4       766         28
#
#        hair_color height last_name middle_name namus_number ncmec_number  \
# count        1337   1337      1337        1337         1337         1337
# unique          8     63      1073         568         1204          357
# top         Brown   67.0  Martinez
# freq          681     97        11         329          134          981
#
#           org     org_contact  \
# count    1337            1337
# unique      5               5
# top     NAMUS  1-855-626-7600
# freq      981             981
#
#                                                 org_name
# count                                               1337 ...
# unique                                                 5 ...
# top     National Missing and Unidentified Persons System ...
# freq                                                 981 ...
#
# [4 rows x 25 columns]

# %% [markdown]
# Which cities in California have the most missing persons?

# %%
cities = Series(df['city'])
cities = cities.value_counts(sort=True).head(n=10)
cities.plot(grid=True, kind='barh', color="#FDD017")

# %% [markdown]
# Which counties in California have the most missing persons?

# %%
counties = Series(df['county'])
counties = counties.value_counts(sort=True, ascending=False).head(n=10)
counties.plot(grid=True, kind='barh', color='#F70D1A')

# %%
sexes = Series(df['sex']).value_counts(sort=True)
print sexes
plt.pie(sexes, labels=sexes.index.values, colors=['#BDEDFF','#FFDFDD', 'black'], autopct='%i%%')
# Out:
# Male      773
# Female    564
# dtype: int64
# ([<matplotlib.patches.Wedge at 0x56ce9d0>,
#   <matplotlib.patches.Wedge at 0x56d10d0>],
#  [<matplotlib.text.Text at 0x56cee90>, <matplotlib.text.Text at 0x56d1510>],
#  [<matplotlib.text.Text at 0x56cef90>, <matplotlib.text.Text at 0x56d15d0>])

# %% [markdown]
# What is the average age of a missing person?

# %%
Series(df['age']).apply(float).mean()
# Out:
# 31.30291697830965
